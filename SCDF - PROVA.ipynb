# %%
# !dir
# Out:
#  O volume na unidade C não tem nome.
#  O Número de Série do Volume é 461A-BF2C
#
#  Pasta de C:\Users\1831133072\Desktop\Prova
#
# 04/12/2018  20:00    <DIR>          .
# 04/12/2018  20:00    <DIR>          ..
# 04/12/2018  19:24    <DIR>          .ipynb_checkpoints
# 04/12/2018  19:31         7.077.406 201710_EmissaoPassagens_SCDP.xlsx
# 04/12/2018  20:00            35.432 Untitled.ipynb
#                2 arquivo(s)      7.112.838 bytes
#                3 pasta(s)   121.952.669.696 bytes disponíveis

# %% [markdown]
# ### Analise de dados - link ->https://www.dropbox.com/sh/g0axgbkt8wq25dn/AABs5PBFtakztm4K0jbp2VyVa?dl=0

# %%
# importar biblioteca
import pandas as pd

# %%
# Ler o arquivo e criar o dataframe
df = pd.read_excel('201710_EmissaoPassagens_SCDP.xlsx', skiprows=3, skipfooter=3)

# verificar a primeira 5 linhas do DataFrame
df.head()
# Out:
#     Código do órgão superior  \
# 0                          3
# 1                          3
# 2                          3
# 3                          3
# 4                          3
#
#                                  Nome do órgão superior                                  \
# 0   Fundação Instituto Brasileiro de Geografia e ...
# 1   Fundação Instituto Brasileiro de Geografia e ...
# 2   Fundação Instituto Brasileiro de Geografia e ...
# 3   Fundação Instituto Brasileiro de Geografia e ...
# 4   Fundação Instituto Brasileiro de Geografia e ...
#
#     Código do órgão solicitante da viagem  \
# 0                                       3
# 1                                       3
# 2                                       3
# 3                                       3
# 4                                       3
#
#                                         Nome do órgão solicitante da viagem                                         \
# ...

# %%
# Vamos olhar as 5 ultimas linhas
df.tail()
# Out:
#         Código do órgão superior  \
# 50400                     219924
# 50401                     219924
# 50402                     219924
# 50403                     219924
# 50404                     219924
#
#                                      Nome do órgão superior                                  \
# 50400   Secretaria-Geral da Presidência da República ...
# 50401   Secretaria-Geral da Presidência da República ...
# 50402   Secretaria-Geral da Presidência da República ...
# 50403   Secretaria-Geral da Presidência da República ...
# 50404   Secretaria-Geral da Presidência da República ...
#
#         Código do órgão solicitante da viagem  \
# 50400                                   84010
# 50401                                   84010
# 50402                                   84010
# 50403                                   34889
# 50404                                   34889
#
# ...

# %%
df.head(1)
# Out:
#     Código do órgão superior  \
# 0                          3
#
#                                  Nome do órgão superior                                  \
# 0   Fundação Instituto Brasileiro de Geografia e ...
#
#     Código do órgão solicitante da viagem  \
# 0                                       3
#
#                                         Nome do órgão solicitante da viagem                                         \
# 0   Fundação Instituto Brasileiro de Geografia e ...
#
#        N. PCDP        N. Reserva/Localizador   Data Emissão Bilhete     \
# 0   028012/17        JGZQXC                    2017-10-03 11:33:35.808
#
#       Data Embarque       Valor Tarifa Comercial  \
# 0   2017-10-06 20:55:00                    407.4
#
#     Percentual Desconto Aplicado           ...             \
# 0                            0.0           ...
#
#               Companhia Aérea                Classe Tarifária Bilhete  \
# 0   LATAM AIRLINES BRASIL                   N
#
# ...

# %%
# Tipos das colunas
df.dtypes
# Out:
#  Código do órgão superior                                                                                             int64
#                                Nome do órgão superior                                                                object
#  Código do órgão solicitante da viagem                                                                                int64
#                                       Nome do órgão solicitante da viagem                                            object
#     N. PCDP                                                                                                          object
#  N. Reserva/Localizador                                                                                              object
#   Data Emissão Bilhete                                                                                               object
# ...

# %%
df.columns
# Out:
# Index([' Código do órgão superior',
#        '                               Nome do órgão superior                                ',
#        ' Código do órgão solicitante da viagem',
#        '                                      Nome do órgão solicitante da viagem                                       ',
#        '    N. PCDP    ', ' N. Reserva/Localizador',
#        '  Data Emissão Bilhete   ', '    Data Embarque    ',
#        ' Valor Tarifa Comercial', ' Percentual Desconto Aplicado',
#        ' Valor Tarifa Governo', ' Valor Tarifa Embarque', ' Valor Bilhete',
#        '           Companhia Aérea            ', ' Classe Tarifária Bilhete',
#        '                                       Regra Tarifária                                       ',
#        ' No Show', ' Remarcado', ' Cancelado', ' Valor Multas',
#        ' Valor Reembolso', ' Diferença de Tarifa', ' Situação Final Bilhete'],
#       dtype='object')

# %%
df = df.rename(columns={' Código do órgão superior':'Código do órgão superior',
                       '                               Nome do órgão superior                                ':'Nome do órgão superior',
                       ' Código do órgão solicitante da viagem':'Código do órgão solicitante da viagem',
                       '                                      Nome do órgão solicitante da viagem                                       ':'Nome do órgão solicitante da viagem',
                       '    N. PCDP    ':'N. PCDP',
                       ' N. Reserva/Localizador':'N. Reserva/Localizador',
                       '  Data Emissão Bilhete   ':'Data Emissão Bilhete',
                       '    Data Embarque    ':'Data Embarque', 
                       ' Valor Tarifa Comercial':'Valor Tarifa Comercial',
                       ' Percentual Desconto Aplicado':'Percentual Desconto Aplicado',
                       ' Valor Tarifa Governo':'Valor Tarifa Governo',
                       ' Valor Tarifa Embarque':'Valor Tarifa Embarque', 
                       ' Valor Bilhete':'Valor Bilhete',
                       '           Companhia Aérea            ':'Companhia Aérea',
                       ' Classe Tarifária Bilhete':'Classe Tarifária Bilhete',
                       '                                       Regra Tarifária                                       ':'Regra Tarifária',
                       ' No Show':'No Show',
                       ' Remarcado':'Remarcado',
                       ' Cancelado':'Cancelado',
                       ' Valor Multas':'Valor Multas',
                       ' Valor Reembolso':'Valor Reembolso',
                       ' Diferença de Tarifa':'Diferença de Tarifa',
                       ' Situação Final Bilhete':'Situação Final Bilhete'})

# %%
df.head()
# Out:
#    Código do órgão superior  \
# 0                         3
# 1                         3
# 2                         3
# 3                         3
# 4                         3
#
#                               Nome do órgão superior  \
# 0   Fundação Instituto Brasileiro de Geografia e ...
# 1   Fundação Instituto Brasileiro de Geografia e ...
# 2   Fundação Instituto Brasileiro de Geografia e ...
# 3   Fundação Instituto Brasileiro de Geografia e ...
# 4   Fundação Instituto Brasileiro de Geografia e ...
#
#    Código do órgão solicitante da viagem  \
# 0                                      3
# 1                                      3
# 2                                      3
# 3                                      3
# 4                                      3
#
#                  Nome do órgão solicitante da viagem          N. PCDP  \
# 0   Fundação Instituto Brasileiro de Geografia e ...   028012/17
# 1   Fundação Instituto Brasileiro de Geografia e ...   028012/17
# ...

# %%
df['Valor Tarifa Governo'].count()
# Out:
# 50405

# %%
df.dtypes
# Out:
# Código do órgão superior                   int64
# Nome do órgão superior                    object
# Código do órgão solicitante da viagem      int64
# Nome do órgão solicitante da viagem       object
# N. PCDP                                   object
# N. Reserva/Localizador                    object
# Data Emissão Bilhete                      object
# Data Embarque                             object
# Valor Tarifa Comercial                   float64
# Percentual Desconto Aplicado             float64
# Valor Tarifa Governo                     float64
# Valor Tarifa Embarque                    float64
# Valor Bilhete                            float64
# Companhia Aérea                           object
# Classe Tarifária Bilhete                  object
# Regra Tarifária                           object
# No Show                                   object
# Remarcado                                 object
# Cancelado                                 object
# ...

# %%
# Tipos e quantidades
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50405 entries, 0 to 50404
# Data columns (total 23 columns):
# Código do órgão superior                 50405 non-null int64
# Nome do órgão superior                   50405 non-null object
# Código do órgão solicitante da viagem    50405 non-null int64
# Nome do órgão solicitante da viagem      50405 non-null object
# N. PCDP                                  50405 non-null object
# N. Reserva/Localizador                   50405 non-null object
# Data Emissão Bilhete                     50405 non-null object
# Data Embarque                            50405 non-null object
# Valor Tarifa Comercial                   50405 non-null float64
# Percentual Desconto Aplicado             50405 non-null float64
# Valor Tarifa Governo                     50405 non-null float64
# Valor Tarifa Embarque                    50405 non-null float64
# Valor Bilhete                            50405 non-null float64
# ...

# %%
# Vamos olhar os valores de Data de lançamento
df['Data Embarque'].value_counts()
# Out:
#  2017-12-02 16:15:00    53
#  2017-10-27 07:55:00    44
#  2017-11-06 09:30:00    42
#  2017-10-22 14:25:00    42
#  2017-11-05 11:45:00    41
#  2017-10-23 17:50:00    41
#  2017-11-11 07:55:00    40
#  2017-10-18 06:15:00    38
#  2017-11-10 16:06:00    36
#  2017-11-22 16:05:00    36
#  2017-10-27 09:50:00    34
#  2017-10-23 08:30:00    34
#  2017-11-06 10:20:00    32
#  2017-10-23 06:05:00    32
#  2017-11-06 17:50:00    31
#  2017-10-29 12:25:00    31
#  2017-11-24 12:00:00    30
#  2017-10-27 21:15:00    30
#  2017-10-29 10:05:00    30
#  2017-10-27 19:05:00    29
#  2017-10-23 09:35:00    29
#  2017-10-24 19:45:00    28
#  2017-10-23 12:10:00    28
#  2017-10-20 18:50:00    28
#  2017-10-20 15:55:00    28
#  2017-11-11 11:15:00    28
#  2017-11-05 12:25:00    28
#  2017-10-19 18:50:00    28
#  2017-10-27 20:35:00    27
#  2017-11-10 19:00:00    27
#                         ..
#  2017-10-25 19:11:00     1
#  2017-10-19 19:56:00     1
#  2017-09-26 20:35:00     1
# ...

# %%
# verificando as companhias aéreas que são Gol linhas aéreas inteligentes
df[df['Companhia Aérea'].str.contains('GOL Linhas')].head()
# Out:
#     Código do órgão superior  \
# 2                          3
# 3                          3
# 4                          3
# 5                          3
# 13                         3
#
#                                Nome do órgão superior  \
# 2    Fundação Instituto Brasileiro de Geografia e ...
# 3    Fundação Instituto Brasileiro de Geografia e ...
# 4    Fundação Instituto Brasileiro de Geografia e ...
# 5    Fundação Instituto Brasileiro de Geografia e ...
# 13   Fundação Instituto Brasileiro de Geografia e ...
#
#     Código do órgão solicitante da viagem  \
# 2                                       3
# 3                                       3
# 4                                       3
# 5                                       3
# 13                                      6
#
#                   Nome do órgão solicitante da viagem          N. PCDP  \
# 2    Fundação Instituto Brasileiro de Geografia e ...   030294/17
# ...

# %%
df['Companhia Aérea'].value_counts()
# Out:
#  GOL Linhas Aéreas Inteligentes           17568
#  LATAM AIRLINES BRASIL                    12301
#  AZUL LINHAS AÉREAS BRASILEIRA            10967
#  AVIANCA S.A.                              9028
#  MAP TRANSPORTES AEREOS LTDA - MAP          274
#  Gol OU Latam - Parceria com Terceiro       267
# Name: Companhia Aérea, dtype: int64

# %%
df['Nome do órgão superior'].value_counts()
# Out:
#  Ministério da Fazenda                                                                   2949
#  Departamento de Polícia Federal                                                         2664
#  Instituto Nacional de Estudos e Pesquisas Educacionais Anísio Teixeira                  2561
#  Ministério da Saúde                                                                     2356
#  Departamento de Polícia Rodoviária Federal                                              1600
#  Instituto Nacional do Seguro Social                                                     1426
#  Comando do Exército                                                                     1315
#  Ministério da Educação                                                                  1170
#  Comando da Aeronáutica                                                                  1156
#  Ministério da Justiça                                                                   1061
# ...

# %%
df[['Valor Tarifa Comercial', 'Percentual Desconto Aplicado','Valor Tarifa Governo']].sample(15)
# Out:
#        Valor Tarifa Comercial  Percentual Desconto Aplicado  \
# 25552                  662.41                           0.0
# 754                    950.90                           0.0
# 50015                  562.60                           0.0
# 46381                  944.80                           3.0
# 33252                  170.10                           0.0
# 21948                  224.90                           3.0
# 15568                  615.00                           3.0
# 20736                  625.90                           3.0
# 45536                  568.90                           3.0
# 6732                   575.00                           3.0
# 34009                  232.70                           0.0
# 4830                  1571.90                           0.0
# 32012                  605.00                           3.0
# 7550                   875.90                           0.0
# 6298                   650.90                           3.0
#
# ...

# %%
#Trabalhando com gráficos
import seaborn as sns

# %%
sns.distplot(df['Valor Tarifa Embarque'])

# %%
sns.distplot(df[df['Nome do órgão superior'].str.contains('Fundação Instituto Brasileiro de Geografia e Estatística')]['Valor Tarifa Governo'].dropna(), label='FIBGE')

# %%
sns.distplot(df[df['Nome do órgão superior'].str.contains('Ministério da Saúde')]['Valor Tarifa Governo'].dropna(), label='MS')

# %%
sns.distplot(df[df['Nome do órgão superior'].str.contains('Departamento de Polícia Rodoviária Federal')]['Valor Tarifa Governo'].dropna(), label='DPF')

# %%
import matplotlib.pyplot as plt

# %%
sns.distplot(df[df['Nome do órgão superior'].str.contains('Fundação Instituto Brasileiro de Geografia e Estatística')]['Valor Tarifa Governo'].dropna(), label='FIBGE')
sns.distplot(df[df['Nome do órgão superior'].str.contains('Ministério da Saúde')]['Valor Tarifa Governo'].dropna(), label='MS')
sns.distplot(df[df['Nome do órgão superior'].str.contains('Departamento de Polícia Rodoviária Federal')]['Valor Tarifa Governo'].dropna(), label='DPF')
plt.legend()

# %%
#bboxplot
sns.boxplot(x='regiao', y='indice_governanca', data=df)
